# %%
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
dfcars = pd.read_csv('https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv')

# %%
# For example, select predictors disp and wt here
lm2 = smf.ols(formula='mpg ~ disp+wt', data=dfcars).fit()
dfcars['predicted']=lm2.params[0]+lm2.params[1]*dfcars['disp']+lm2.params[2]*dfcars['wt']

# %%
fig, ax = plt.subplots()
plt.scatter(dfcars['mpg'], dfcars['predicted'])
p1 = max(max(dfcars['predicted']), max(dfcars['mpg']))
p2 = min(min(dfcars['predicted']), min(dfcars['mpg']))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Multiple Regression Predictions')
ax.set_aspect(1)
plt.show()
